# %% [markdown]
# ## 요기요 데이터 전처리

# %% [markdown]
# 기본적으로 null 값이 있는지 확인하고 야놀자 데이터 열이름과 동일하게 바꿀 것.

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("C:/Users/yeonj/OneDrive/바탕 화면/data_crawling/data/combined_yeogi_data.csv")
df.head()
# Out:
# C:\Users\yeonj\AppData\Local\Temp\ipykernel_19260\2887390748.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/combined_yeogi_data.csv")
#      호텔 이름  평점                                              리뷰 내용         작성일  \
# 0  유성 메이호텔   5  매우매우 만족합니다 깨끗하고 시설도좋고 주변에 먹을것도많고 주차자리도 매우매우 널널...  2024-10-18
# 1  유성 메이호텔   4  주변에 숙소가 많은데 다른숙소를 주로 이용하다 이번에 처음 이용해보았는데 객실도 너...  2024-10-18
# 2  유성 메이호텔   5  봉명동 술집에서 술마실때 위치가 너무 좋아요! 항상 찾는곳으로 주차장도 지상도 있고...  2024-10-28
# 3  유성 메이호텔   5  짐 놓고갔엇는데 프론트 분 이 되게 친절하셨었어요 아아 송주차장이 없지만 그래도 주...  2024-10-29
# 4  유성 메이호텔   4  🍀할머니 댁같은 느낌🍀\r\n📍객실\r\n깔끔한데 오래된 느낌은 못 지우겠어요. 전...  2024-11-05
#
#    숙박 가격                 위치   구역
# 0  60000  대전 유성구 봉명동 551-17  유성구
# 1  60000  대전 유성구 봉명동 551-17  유성구
# 2  60000  대전 유성구 봉명동 551-17  유성구
# 3  60000  대전 유성구 봉명동 551-17  유성구
# 4  60000  대전 유성구 봉명동 551-17  유성구

# %% [markdown]
# ## 1. 결측치 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187167 entries, 0 to 187166
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   호텔 이름   187167 non-null  object
#  1   평점      187167 non-null  int64
#  2   리뷰 내용   187167 non-null  object
#  3   작성일     187167 non-null  object
#  4   숙박 가격   187167 non-null  object
#  5   위치      187167 non-null  object
#  6   구역      187167 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 10.0+ MB

# %%
# 한국어로 된 열 이름 변경
df.rename(columns={
    '호텔 이름': 'hotel',
    '평점': 'star',
    '리뷰 내용': 'review',
    '작성일': 'date',
    '숙박 가격': 'price',
    '위치': 'address',
    '구역': 'district'
}, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187167 entries, 0 to 187166
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   hotel     187167 non-null  object
#  1   star      187167 non-null  int64
#  2   review    187167 non-null  object
#  3   date      187167 non-null  object
#  4   price     187167 non-null  object
#  5   address   187167 non-null  object
#  6   district  187167 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 10.0+ MB

# %% [markdown]
# ## 3. data 날짜 전처리

# %%
df
# Out:
#              hotel  star                                             review  \
# 0          유성 메이호텔     5  매우매우 만족합니다 깨끗하고 시설도좋고 주변에 먹을것도많고 주차자리도 매우매우 널널...
# 1          유성 메이호텔     4  주변에 숙소가 많은데 다른숙소를 주로 이용하다 이번에 처음 이용해보았는데 객실도 너...
# 2          유성 메이호텔     5  봉명동 술집에서 술마실때 위치가 너무 좋아요! 항상 찾는곳으로 주차장도 지상도 있고...
# 3          유성 메이호텔     5  짐 놓고갔엇는데 프론트 분 이 되게 친절하셨었어요 아아 송주차장이 없지만 그래도 주...
# 4          유성 메이호텔     4  🍀할머니 댁같은 느낌🍀\r\n📍객실\r\n깔끔한데 오래된 느낌은 못 지우겠어요. 전...
# ...            ...   ...                                                ...
# 187162  호텔 그레이톤 둔산     2                            예전에는 안그랬는데, 요즘은 모텔이 된듯함
# 187163  호텔 그레이톤 둔산     2  시청엳에서도 가깝고 주변 조용하규 음식점 카페 다 많아서 이용하기 좋아요! 다른 리...
# 187164  호텔 그레이톤 둔산     2  온수 한명이 쓰면 20분동안 안나온다는 걸 체크인할 때 들었습니다. \r\n미리 주...
# 187165  호텔 그레이톤 둔산     1                         담배냄새 찌든냄새 최악..\r\n침대도 별로..
# 187166  호텔 그레이톤 둔산     2  밥이 맛있다고 리뷰보고 가게 되었는데,\r\n뭐 특별히 기억에 남을 만한건 아니고,...
#
#               date  price            address district
# ...

# %% [markdown]
# 2024-10-18 이 형태를 2024.10.18로 맞추기

# %%
df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y.%m.%d')
df
# Out:
#              hotel  star                                             review  \
# 0          유성 메이호텔     5  매우매우 만족합니다 깨끗하고 시설도좋고 주변에 먹을것도많고 주차자리도 매우매우 널널...
# 1          유성 메이호텔     4  주변에 숙소가 많은데 다른숙소를 주로 이용하다 이번에 처음 이용해보았는데 객실도 너...
# 2          유성 메이호텔     5  봉명동 술집에서 술마실때 위치가 너무 좋아요! 항상 찾는곳으로 주차장도 지상도 있고...
# 3          유성 메이호텔     5  짐 놓고갔엇는데 프론트 분 이 되게 친절하셨었어요 아아 송주차장이 없지만 그래도 주...
# 4          유성 메이호텔     4  🍀할머니 댁같은 느낌🍀\r\n📍객실\r\n깔끔한데 오래된 느낌은 못 지우겠어요. 전...
# ...            ...   ...                                                ...
# 187162  호텔 그레이톤 둔산     2                            예전에는 안그랬는데, 요즘은 모텔이 된듯함
# 187163  호텔 그레이톤 둔산     2  시청엳에서도 가깝고 주변 조용하규 음식점 카페 다 많아서 이용하기 좋아요! 다른 리...
# 187164  호텔 그레이톤 둔산     2  온수 한명이 쓰면 20분동안 안나온다는 걸 체크인할 때 들었습니다. \r\n미리 주...
# 187165  호텔 그레이톤 둔산     1                         담배냄새 찌든냄새 최악..\r\n침대도 별로..
# 187166  호텔 그레이톤 둔산     2  밥이 맛있다고 리뷰보고 가게 되었는데,\r\n뭐 특별히 기억에 남을 만한건 아니고,...
#
#               date  price            address district
# ...

# %%
df.to_csv('C:/Users/yeonj/OneDrive/바탕 화면/data_crawling/data/combined_yeogi_data.csv', index=False, encoding='utf-8')
